# %% [markdown]
# ## **Installation Of Required Library**

# %%
# !pip install comet_llm
# !pip install nest_asyncio langchain-openai langchain_community
# !pip install nest_asyncio langchain-openai langchain_community
# !pip install playwright
# !playwright install
# Out:
# Collecting comet_llm
#   Downloading comet_llm-2.2.4-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 2.9 MB/s eta 0:00:00
# Collecting comet-ml>=3.40.0 (from comet_llm)
#   Downloading comet_ml-3.42.0-py3-none-any.whl (663 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.1/663.1 kB 9.3 MB/s eta 0:00:00
# Collecting flatten-dict (from comet_llm)
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from comet_llm) (2.31.0)
# Collecting types-requests (from comet_llm)
#   Downloading types_requests-2.31.0.20240406-py3-none-any.whl (15 kB)
# Collecting everett[ini]<3.2.0,>=1.0.1 (from comet-ml>=3.40.0->comet_llm)
#   Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml>=3.40.0->comet_llm) (4.19.2)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet-ml>=3.40.0->comet_llm) (5.9.5)
# Collecting python-box<7.0.0 (from comet-ml>=3.40.0->comet_llm)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 19.1 MB/s eta 0:00:00
# Collecting requests-toolbelt>=0.8.0 (from comet-ml>=3.40.0->comet_llm)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.3 MB/s eta 0:00:00
# Collecting semantic-version>=2.8.0 (from comet-ml>=3.40.0->comet_llm)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting sentry-sdk>=1.1.0 (from comet-ml>=3.40.0->comet_llm)
#   Downloading sentry_sdk-2.2.0-py2.py3-none-any.whl (281 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.1/281.1 kB 25.9 MB/s eta 0:00:00
# Collecting simplejson (from comet-ml>=3.40.0->comet_llm)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from comet-ml>=3.40.0->comet_llm) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet-ml>=3.40.0->comet_llm) (2.0.7)
# Requirement already satisfied: websocket-client!=1.4.0,>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml>=3.40.0->comet_llm) (1.8.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml>=3.40.0->comet_llm) (1.14.1)
# Collecting wurlitzer>=1.0.2 (from comet-ml>=3.40.0->comet_llm)
#   Downloading wurlitzer-3.1.0-py3-none-any.whl (8.4 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet-ml>=3.40.0->comet_llm)
#   Downloading dulwich-0.22.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (979 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 979.1/979.1 kB 32.3 MB/s eta 0:00:00
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml>=3.40.0->comet_llm) (13.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->comet_llm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->comet_llm) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->comet_llm) (2024.2.2)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet-ml>=3.40.0->comet_llm)
#   Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.40.0->comet_llm) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.40.0->comet_llm) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.40.0->comet_llm) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.40.0->comet_llm) (0.18.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet-ml>=3.40.0->comet_llm) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet-ml>=3.40.0->comet_llm) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet-ml>=3.40.0->comet_llm) (0.1.2)
# Installing collected packages: everett, wurlitzer, types-requests, simplejson, sentry-sdk, semantic-version, python-box, flatten-dict, dulwich, configobj, requests-toolbelt, comet-ml, comet_llm
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# Successfully installed comet-ml-3.42.0 comet_llm-2.2.4 configobj-5.0.8 dulwich-0.22.1 everett-3.1.0 flatten-dict-0.4.2 python-box-6.1.0 requests-toolbelt-1.0.0 semantic-version-2.10.0 sentry-sdk-2.2.0 simplejson-3.19.2 types-requests-2.31.0.20240406 wurlitzer-3.1.0
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Collecting langchain-openai
#   Downloading langchain_openai-0.1.7-py3-none-any.whl (34 kB)
# Collecting langchain_community
#   Downloading langchain_community-0.2.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.8 MB/s eta 0:00:00
# Collecting langchain-core<0.3,>=0.1.46 (from langchain-openai)
#   Downloading langchain_core-0.2.0-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.9/307.9 kB 17.4 MB/s eta 0:00:00
# Collecting openai<2.0.0,>=1.24.0 (from langchain-openai)
#   Downloading openai-1.30.1-py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 19.4 MB/s eta 0:00:00
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Collecting langchain<0.3.0,>=0.2.0 (from langchain_community)
#   Downloading langchain-0.2.0-py3-none-any.whl (973 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.7/973.7 kB 27.3 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain_community)
#   Downloading langsmith-0.1.59-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 7.5 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.0->langchain_community)
#   Downloading langchain_text_splitters-0.2.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (2.7.1)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3,>=0.1.46->langchain-openai)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.3,>=0.1.46->langchain-openai)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.3 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain_community)
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.24.0->langchain-openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2023.12.25)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.24.0->langchain-openai) (1.2.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.6 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.9 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.46->langchain-openai)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (2.18.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: packaging, orjson, mypy-extensions, jsonpointer, h11, typing-inspect, tiktoken, marshmallow, jsonpatch, httpcore, langsmith, httpx, dataclasses-json, openai, langchain-core, langchain-text-splitters, langchain-openai, langchain, langchain_community
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.6 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jsonpatch-1.33 jsonpointer-2.4 langchain-0.2.0 langchain-core-0.2.0 langchain-openai-0.1.7 langchain-text-splitters-0.2.0 langchain_community-0.2.0 langsmith-0.1.59 marshmallow-3.21.2 mypy-extensions-1.0.0 openai-1.30.1 orjson-3.10.3 packaging-23.2 tiktoken-0.7.0 typing-inspect-0.9.0
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.10/dist-packages (0.1.7)
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: langchain-core<0.3,>=0.1.46 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (0.2.0)
# Requirement already satisfied: openai<2.0.0,>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (1.30.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.6.6)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.2.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.1.59)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (0.2.0)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (2.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (0.27.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2023.12.25)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.24.0->langchain-openai) (1.2.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.46->langchain-openai) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (2.18.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Collecting playwright
#   Downloading playwright-1.44.0-py3-none-manylinux1_x86_64.whl (37.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: greenlet==3.0.3 in /usr/local/lib/python3.10/dist-packages (from playwright) (3.0.3)
# Collecting pyee==11.1.0 (from playwright)
#   Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee==11.1.0->playwright) (4.11.0)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.44.0 pyee-11.1.0
# Downloading Chromium 125.0.6422.26 (playwright build v1117) from https://playwright.azureedge.net/builds/chromium/1117/chromium-linux.zip
# 156.8 MiB [] 0% 0.0s156.8 MiB [] 0% 24.5s156.8 MiB [] 0% 15.8s156.8 MiB [] 0% 11.1s156.8 MiB [] 0% 9.7s156.8 MiB [] 1% 8.1s156.8 MiB [] 1% 7.5s156.8 MiB [] 1% 6.8s156.8 MiB [] 2% 6.1s156.8 MiB [] 2% 5.6s156.8 MiB [] 3% 5.3s156.8 MiB [] 3% 5.0s156.8 MiB [] 4% 4.7s156.8 MiB [] 4% 4.5s156.8 MiB [] 5% 4.2s156.8 MiB [] 6% 4.0s156.8 MiB [] 6% 4.1s156.8 MiB [] 7% 3.9s156.8 MiB [] 8% 3.7s156.8 MiB [] 9% 3.6s156.8 MiB [] 9% 3.4s156.8 MiB [] 10% 3.3s156.8 MiB [] 11% 3.1s156.8 MiB [] 12% 3.0s156.8 MiB [] 13% 2.8s156.8 MiB [] 14% 2.7s156.8 MiB [] 15% 2.7s156.8 MiB [] 16% 2.6s156.8 MiB [] 17% 2.5s156.8 MiB [] 18% 2.4s156.8 MiB [] 19% 2.2s156.8 MiB [] 20% 2.1s156.8 MiB [] 21% 2.1s156.8 MiB [] 22% 2.0s156.8 MiB [] 24% 1.9s156.8 MiB [] 25% 1.8s156.8 MiB [] 26% 1.8s156.8 MiB [] 27% 1.8s156.8 MiB [] 28% 1.7s156.8 MiB [] 29% 1.7s156.8 MiB [] 30% 1.7s156.8 MiB [] 31% 1.6s156.8 MiB [] 32% 1.6s156.8 MiB [] 33% 1.6s156.8 MiB [] 35% 1.5s156.8 MiB [] 36% 1.5s156.8 MiB [] 37% 1.4s156.8 MiB [] 38% 1.4s156.8 MiB [] 40% 1.3s156.8 MiB [] 41% 1.3s156.8 MiB [] 42% 1.2s156.8 MiB [] 44% 1.2s156.8 MiB [] 45% 1.1s156.8 MiB [] 46% 1.1s156.8 MiB [] 48% 1.1s156.8 MiB [] 49% 1.0s156.8 MiB [] 50% 1.0s156.8 MiB [] 52% 0.9s156.8 MiB [] 53% 0.9s156.8 MiB [] 55% 0.9s156.8 MiB [] 56% 0.8s156.8 MiB [] 57% 0.8s156.8 MiB [] 59% 0.8s156.8 MiB [] 60% 0.7s156.8 MiB [] 62% 0.7s156.8 MiB [] 63% 0.7s156.8 MiB [] 64% 0.6s156.8 MiB [] 65% 0.6s156.8 MiB [] 67% 0.6s156.8 MiB [] 68% 0.6s156.8 MiB [] 69% 0.5s156.8 MiB [] 70% 0.5s156.8 MiB [] 73% 0.5s156.8 MiB [] 74% 0.4s156.8 MiB [] 76% 0.4s156.8 MiB [] 77% 0.4s156.8 MiB [] 79% 0.4s156.8 MiB [] 80% 0.3s156.8 MiB [] 82% 0.3s156.8 MiB [] 83% 0.3s156.8 MiB [] 85% 0.2s156.8 MiB [] 86% 0.2s156.8 MiB [] 88% 0.2s156.8 MiB [] 89% 0.2s156.8 MiB [] 91% 0.1s156.8 MiB [] 92% 0.1s156.8 MiB [] 93% 0.1s156.8 MiB [] 94% 0.1s156.8 MiB [] 95% 0.1s156.8 MiB [] 97% 0.0s156.8 MiB [] 98% 0.0s156.8 MiB [] 100% 0.0s
# Chromium 125.0.6422.26 (playwright build v1117) downloaded to /root/.cache/ms-playwright/chromium-1117
# Downloading FFMPEG playwright build v1009 from https://playwright.azureedge.net/builds/ffmpeg/1009/ffmpeg-linux.zip
# 2.6 MiB [] 0% 0.0s2.6 MiB [] 3% 0.4s2.6 MiB [] 9% 0.3s2.6 MiB [] 26% 0.1s2.6 MiB [] 58% 0.0s2.6 MiB [] 84% 0.0s2.6 MiB [] 100% 0.0s
# FFMPEG playwright build v1009 downloaded to /root/.cache/ms-playwright/ffmpeg-1009
# Downloading Firefox 125.0.1 (playwright build v1449) from https://playwright.azureedge.net/builds/firefox/1449/firefox-ubuntu-22.04.zip
# 85.7 MiB [] 0% 0.0s85.7 MiB [] 0% 14.7s85.7 MiB [] 0% 8.9s85.7 MiB [] 1% 4.8s85.7 MiB [] 1% 3.3s85.7 MiB [] 2% 2.7s85.7 MiB [] 3% 2.4s85.7 MiB [] 4% 2.3s85.7 MiB [] 5% 2.3s85.7 MiB [] 7% 2.1s85.7 MiB [] 8% 2.1s85.7 MiB [] 9% 2.1s85.7 MiB [] 9% 2.0s85.7 MiB [] 10% 2.0s85.7 MiB [] 11% 1.9s85.7 MiB [] 12% 1.9s85.7 MiB [] 13% 2.0s85.7 MiB [] 13% 2.1s85.7 MiB [] 14% 2.1s85.7 MiB [] 15% 2.0s85.7 MiB [] 16% 2.0s85.7 MiB [] 17% 2.1s85.7 MiB [] 18% 2.1s85.7 MiB [] 19% 2.0s85.7 MiB [] 20% 1.9s85.7 MiB [] 21% 1.9s85.7 MiB [] 23% 1.8s85.7 MiB [] 24% 1.7s85.7 MiB [] 25% 1.7s85.7 MiB [] 26% 1.6s85.7 MiB [] 28% 1.5s85.7 MiB [] 29% 1.5s85.7 MiB [] 30% 1.4s85.7 MiB [] 32% 1.4s85.7 MiB [] 33% 1.3s85.7 MiB [] 35% 1.2s85.7 MiB [] 37% 1.2s85.7 MiB [] 38% 1.1s85.7 MiB [] 40% 1.1s85.7 MiB [] 41% 1.1s85.7 MiB [] 42% 1.0s85.7 MiB [] 44% 1.0s85.7 MiB [] 45% 1.0s85.7 MiB [] 46% 0.9s85.7 MiB [] 47% 0.9s85.7 MiB [] 49% 0.9s85.7 MiB [] 51% 0.8s85.7 MiB [] 53% 0.8s85.7 MiB [] 55% 0.7s85.7 MiB [] 55% 0.8s85.7 MiB [] 56% 0.8s85.7 MiB [] 57% 0.8s85.7 MiB [] 58% 0.8s85.7 MiB [] 60% 0.7s85.7 MiB [] 61% 0.7s85.7 MiB [] 63% 0.7s85.7 MiB [] 65% 0.6s85.7 MiB [] 66% 0.6s85.7 MiB [] 67% 0.6s85.7 MiB [] 68% 0.6s85.7 MiB [] 69% 0.5s85.7 MiB [] 70% 0.5s85.7 MiB [] 71% 0.5s85.7 MiB [] 72% 0.5s85.7 MiB [] 73% 0.5s85.7 MiB [] 74% 0.5s85.7 MiB [] 75% 0.4s85.7 MiB [] 77% 0.4s85.7 MiB [] 78% 0.4s85.7 MiB [] 79% 0.4s85.7 MiB [] 80% 0.3s85.7 MiB [] 81% 0.3s85.7 MiB [] 82% 0.3s85.7 MiB [] 83% 0.3s85.7 MiB [] 84% 0.3s85.7 MiB [] 86% 0.2s85.7 MiB [] 87% 0.2s85.7 MiB [] 88% 0.2s85.7 MiB [] 89% 0.2s85.7 MiB [] 90% 0.2s85.7 MiB [] 92% 0.1s85.7 MiB [] 93% 0.1s85.7 MiB [] 94% 0.1s85.7 MiB [] 95% 0.1s85.7 MiB [] 96% 0.1s85.7 MiB [] 98% 0.0s85.7 MiB [] 100% 0.0s
# Firefox 125.0.1 (playwright build v1449) downloaded to /root/.cache/ms-playwright/firefox-1449
# Downloading Webkit 17.4 (playwright build v2003) from https://playwright.azureedge.net/builds/webkit/2003/webkit-ubuntu-22.04.zip
# 84.8 MiB [] 0% 0.0s84.8 MiB [] 0% 38.4s84.8 MiB [] 0% 45.8s84.8 MiB [] 0% 43.5s84.8 MiB [] 0% 41.5s84.8 MiB [] 0% 43.0s84.8 MiB [] 0% 44.9s84.8 MiB [] 0% 46.9s84.8 MiB [] 0% 47.6s84.8 MiB [] 0% 48.5s84.8 MiB [] 0% 49.0s84.8 MiB [] 0% 49.6s84.8 MiB [] 0% 49.7s84.8 MiB [] 0% 50.3s84.8 MiB [] 0% 50.6s84.8 MiB [] 0% 50.9s84.8 MiB [] 0% 51.4s84.8 MiB [] 0% 51.3s84.8 MiB [] 0% 51.6s84.8 MiB [] 0% 51.8s84.8 MiB [] 0% 52.0s84.8 MiB [] 0% 52.1s84.8 MiB [] 0% 52.5s84.8 MiB [] 0% 52.8s84.8 MiB [] 1% 52.9s84.8 MiB [] 1% 53.0s84.8 MiB [] 1% 53.2s84.8 MiB [] 1% 53.3s84.8 MiB [] 1% 53.4s84.8 MiB [] 1% 53.3s84.8 MiB [] 1% 53.4s84.8 MiB [] 1% 53.5s84.8 MiB [] 1% 53.6s84.8 MiB [] 1% 53.8s84.8 MiB [] 1% 53.7s84.8 MiB [] 1% 53.9s84.8 MiB [] 1% 53.8s84.8 MiB [] 2% 53.8s84.8 MiB [] 2% 53.7s84.8 MiB [] 2% 53.8s84.8 MiB [] 2% 53.7s84.8 MiB [] 2% 53.6s84.8 MiB [] 2% 53.7s84.8 MiB [] 2% 53.6s84.8 MiB [] 2% 53.7s84.8 MiB [] 2% 53.6s84.8 MiB [] 2% 53.5s84.8 MiB [] 3% 53.6s84.8 MiB [] 3% 53.5s84.8 MiB [] 3% 53.4s84.8 MiB [] 3% 53.3s84.8 MiB [] 3% 53.2s84.8 MiB [] 3% 53.1s84.8 MiB [] 3% 53.0s84.8 MiB [] 5% 38.9s84.8 MiB [] 5% 34.2s84.8 MiB [] 7% 26.3s84.8 MiB [] 9% 21.0s84.8 MiB [] 10% 17.8s84.8 MiB [] 11% 16.0s84.8 MiB [] 12% 14.6s84.8 MiB [] 15% 12.1s84.8 MiB [] 16% 10.7s84.8 MiB [] 19% 9.3s84.8 MiB [] 20% 8.7s84.8 MiB [] 21% 8.1s84.8 MiB [] 22% 7.8s84.8 MiB [] 23% 7.5s84.8 MiB [] 23% 7.4s84.8 MiB [] 24% 7.2s84.8 MiB [] 25% 6.7s84.8 MiB [] 26% 6.4s84.8 MiB [] 27% 6.1s84.8 MiB [] 29% 5.7s84.8 MiB [] 30% 5.4s84.8 MiB [] 32% 5.0s84.8 MiB [] 34% 4.6s84.8 MiB [] 36% 4.3s84.8 MiB [] 37% 4.0s84.8 MiB [] 38% 3.9s84.8 MiB [] 40% 3.7s84.8 MiB [] 41% 3.6s84.8 MiB [] 42% 3.4s84.8 MiB [] 44% 3.2s84.8 MiB [] 45% 3.1s84.8 MiB [] 46% 2.9s84.8 MiB [] 47% 2.8s84.8 MiB [] 49% 2.7s84.8 MiB [] 50% 2.6s84.8 MiB [] 52% 2.4s84.8 MiB [] 54% 2.3s84.8 MiB [] 55% 2.2s84.8 MiB [] 57% 2.0s84.8 MiB [] 58% 1.9s84.8 MiB [] 60% 1.8s84.8 MiB [] 62% 1.7s84.8 MiB [] 63% 1.6s84.8 MiB [] 64% 1.5s84.8 MiB [] 66% 1.4s84.8 MiB [] 68% 1.3s84.8 MiB [] 69% 1.2s84.8 MiB [] 70% 1.2s84.8 MiB [] 72% 1.1s84.8 MiB [] 73% 1.1s84.8 MiB [] 74% 1.0s84.8 MiB [] 75% 1.0s84.8 MiB [] 76% 0.9s84.8 MiB [] 77% 0.9s84.8 MiB [] 78% 0.8s84.8 MiB [] 79% 0.8s84.8 MiB [] 80% 0.7s84.8 MiB [] 81% 0.7s84.8 MiB [] 83% 0.6s84.8 MiB [] 84% 0.6s84.8 MiB [] 86% 0.5s84.8 MiB [] 87% 0.4s84.8 MiB [] 89% 0.4s84.8 MiB [] 91% 0.3s84.8 MiB [] 92% 0.2s84.8 MiB [] 94% 0.2s84.8 MiB [] 96% 0.1s84.8 MiB [] 98% 0.1s84.8 MiB [] 99% 0.0s84.8 MiB [] 100% 0.0s
# Webkit 17.4 (playwright build v2003) downloaded to /root/.cache/ms-playwright/webkit-2003
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:216:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:603:43)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:701:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:690:43)
#     at async t.<anonymous> (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/cli/program.js:119:7)

# %% [markdown]
# ## **Import Required Library**

# %%
from google.colab import userdata
import nest_asyncio
nest_asyncio.apply()

# Import required modules from langchain
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import AsyncChromiumLoader
from langchain_community.document_transformers import BeautifulSoupTransformer
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import create_extraction_chain
import time
import pandas as pd
import comet_llm

# Initialize a Comet project
comet_llm.init(project="langchain-web-scraping",
               api_key=MY_COMET_KEY,
               )
# Out:
# COMET INFO: Valid Comet API Key saved in /content/drive/MyDrive/.comet.config (set COMET_CONFIG to change where it is saved).

# %% [markdown]
# To get the OpenAI API key : Go to https://help.openai.com/en/articles/4936850-where-do-i-find-my-api-key
#
# To get the Comet API Key: Go to https://www.comet.com/docs/v2/api-and-sdk/rest-api/overview/

# %%
#api key acces
MY_OPENAI_KEY=userdata.get('MY_OPENAI_KEY')
MY_COMET_KEY=userdata.get('MY_COMET_KEY')

# %% [markdown]
# ## **Web scrapping Using OpenAI GPT-3.5 Turbo LLM**

# %%
import nest_asyncio
import time
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import AsyncChromiumLoader
from langchain_community.document_transformers import BeautifulSoupTransformer
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import create_extraction_chain
from google.colab import userdata
import comet_llm

nest_asyncio.apply()

MY_OPENAI_KEY = "YOUR_OPENAI_KEY"
MY_COMET_KEY = "YOUR_COMET_KEY"

comet_llm.init(project="langchain-web-scraping", api_key=MY_COMET_KEY)

html_tags = [
    "h1", "h2", "h3", "h4", "h5", "h6",
    "p",
    "span",
    "div",
    "ul", "ol", "li",
    "table", "tr", "th", "td",
    "a",
    "b", "strong",
    "i", "em",
    "blockquote", "q", "cite",
    "code", "pre",
    "form", "input", "textarea", "label",
    "dl", "dt", "dd",
    "article",
    "section",
    "nav",
    "aside",
    "header",
    "footer",
    "main",
    "figure", "figcaption",
    "details", "summary",
    "mark",
    "time"
]

def extract_url(url):
    print(url)
    url_loader = AsyncChromiumLoader([url])
    url_docs = url_loader.load()
    bs_transformer = BeautifulSoupTransformer()
    url_transfornm = bs_transformer.transform_documents(
        url_docs, tags_to_extract=["a"]
    )
    llm = ChatOpenAI(openai_api_key=MY_OPENAI_KEY)
    url_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=15000, chunk_overlap=0)
    url_splits = url_splitter.split_documents(url_transfornm)

    url_schema = {
        "properties": {
            "url": {"type": "string"},
        },
        "required": ["url"],
    }
    url_list = []

    if len(url_splits) > 0:
        start_time = time.time()
        extracted_content = create_extraction_chain(schema=url_schema, llm=llm).run(url_splits[0].page_content)
        end_time = time.time()
        comet_llm.log_prompt(
            prompt=str(url_splits[0].page_content),
            metadata={"schema": url_schema},
            output=extracted_content,
            duration=end_time - start_time,
        )
        url_list = [d['url'] for d in extracted_content]

    return url_list

def extract_content(urls):
    contents = []
    for url in urls:
        url_loader = AsyncChromiumLoader([url])
        content_docs = url_loader.load()
        bs_transformer = BeautifulSoupTransformer()
        content_transfornm = bs_transformer.transform_documents(content_docs, tags_to_extract=html_tags)
        content = content_transfornm[0].page_content
        contents.append(content)
    return contents

class Document:
    def __init__(self, page_content, metadata):
        self.page_content = page_content
        self.metadata = metadata

    def __repr__(self):
        return f'Document(page_content="{self.page_content},metadata={self.metadata} ")'

def generate_output(resulted_content):
    llm = ChatOpenAI(openai_api_key=MY_OPENAI_KEY)
    splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=15000, chunk_overlap=0)
    splits = splitter.split_documents(resulted_content)
    schema = {
        "properties": {
            "original_id": {"type": "string", "description": "Unique from source"},
            "aug_id": {"type": "string", "description": "Augmented identifier from the context"},
            "country_name": {"type": "string", "description": "Name of the Country"},
            "country_code": {"type": "string", "description": "ISO 3-letter Country Code"},
            "map_coordinates": {
                "type": "object",
                "description": "Geo Point of the region formatted as {'type': 'Point', 'coordinates': [longitude, latitude]}",
                "properties": {"type": {"type": "string"}, "coordinates": {"type": "array", "items": {"type": "number"}}},
            },
            "url": {"type": "string", "description": "Url of the website of the source", "format": "uri"},
            "region_name": {"type": "string", "description": "Region Name for a Country according to World Bank Standards"},
            "region_code": {"type": "string", "description": "Region code for a Region according to World Bank Standards"},
            "Project_title": {"type": "string", "description": "A title for this tender/project used as a headline"},
            "Project_description": {"type": "string", "description": "A summary description of the tender/project"},
            "status": {"type": "string", "description": "The current status of the tender/project from the closed tenderStatus codelist"},
            "stages": {"type": "string", "description": "Stages of the tender/project"},
            "date": {"type": "string", "description": "The date on which the information was first recorded or published", "format": "date"},
            "procurementMethod": {"type": "string", "description": "The procedure used to purchase the relevant works, goods or services"},
            "budget": {"type": "number", "description": "The total upper estimated value of the procurement"},
            "currency": {"type": "string", "description": "The currency for each amount specified using the uppercase 3-letter code from ISO4217"},
            "buyer": {"type": "string", "description": "Entity whose budget will be used to pay for related goods, works or services"},
            "sector": {"type": "string", "description": "A high-level categorization of the main sector this procurement process relates to"},
            "subsector": {"type": "string", "description": "A further subdivision of the sector the procurement process belongs to"},
        },
        "required": [
            "original_id", "aug_id", "country_name", "country_code", "map_coordinates", "url",
            "region_name", "region_code", "title", "description", "status", "stages", "date",
            "procurementMethod", "budget", "currency", "buyer", "sector", "subsector"
        ]
    }

    if len(splits) > 0:
        start_time = time.time()
        extracted_content = create_extraction_chain(schema=schema, llm=llm).run(splits[0].page_content)
        end_time = time.time()

        comet_llm.log_prompt(
            prompt=str(splits[0].page_content),
            metadata={"schema": schema},
            output=extracted_content,
            duration=end_time - start_time,
        )

    return extracted_content
# Out:
# COMET INFO: Valid Comet API Key saved in /content/drive/MyDrive/.comet.config (set COMET_CONFIG to change where it is saved).

# %% [markdown]
# **Scraping  the data from the given URL and reseachered and found URL for construction and infrastructure projects and tenders in the state of California.**

# %%
Given_12url_list=['https://www.ci.richmond.ca.us/1404/Major-Projects', 'https://www.bakersfieldcity.us/518/Projects-Programs', 'https://www.cityofwasco.org/311/Current-Projects', 'https://www.eurekaca.gov/744/Upcoming-Projects', 'https://www.cityofarcata.org/413/Current-City-Construction-Projects', 'https://www.mckinleyvillecsd.com/news-and-project-updates', 'https://www.cityofsanrafael.org/major-planning-projects-2/', 'https://www.novato.org/government/community-development/planning-division/planning-projects?locale=en', 'https://www.cityofmillvalley.org/258/Projects', 'https://riversideca.gov/utilities/projects', 'https://www.moval.org/cdd/documents/about-projects.html', 'https://www.coronaca.gov/government/departments-divisions/department-of-water-and-power/construction', 'http://www.cityofsacramento.org/public-works/engineering-services/projects']
own_8url_list=['https://data.ca.gov/dataset/?q=construction+and+infrastructure+projects&sort=score+desc%2C+metadata_modified+desc', 'https://dot.ca.gov/programs/procurement-and-contracts/bid-opportunities', 'https://www.cityofarcata.org/413/Current-City-Construction-Projects', 'https://www.cityofsanrafael.org/major-planning-projects-2/', 'https://www.elkgrovecity.org/southeast-policy-area/development-projects', 'https://www.fluor.com/market-reach/industries/infrastructure', 'https://www.fluor.com/projects', 'https://www.toaks.org/departments/public-works/construction']
Final_list=Given_12url_list + own_8url_list

# %%
print(Final_list)
print(len(Final_list))
# Out:
# ['https://www.ci.richmond.ca.us/1404/Major-Projects', 'https://www.bakersfieldcity.us/518/Projects-Programs', 'https://www.cityofwasco.org/311/Current-Projects', 'https://www.eurekaca.gov/744/Upcoming-Projects', 'https://www.cityofarcata.org/413/Current-City-Construction-Projects', 'https://www.mckinleyvillecsd.com/news-and-project-updates', 'https://www.cityofsanrafael.org/major-planning-projects-2/', 'https://www.novato.org/government/community-development/planning-division/planning-projects?locale=en', 'https://www.cityofmillvalley.org/258/Projects', 'https://riversideca.gov/utilities/projects', 'https://www.moval.org/cdd/documents/about-projects.html', 'https://www.coronaca.gov/government/departments-divisions/department-of-water-and-power/construction', 'http://www.cityofsacramento.org/public-works/engineering-services/projects', 'https://data.ca.gov/dataset/?q=construction+and+infrastructure+projects&sort=score+desc%2C+metadata_modified+desc', 'https://dot.ca.gov/programs/procurement-and-contracts/bid-opportunities', 'https://www.cityofarcata.org/413/Current-City-Construction-Projects', 'https://www.cityofsanrafael.org/major-planning-projects-2/', 'https://www.elkgrovecity.org/southeast-policy-area/development-projects', 'https://www.fluor.com/market-reach/industries/infrastructure', 'https://www.fluor.com/projects', 'https://www.toaks.org/departments/public-works/construction']
# 21

# %%
finalDict=[]
for url in Final_list:
  url_list=[]
  url_list=extract_url(url)
  url_list.append(url)

  output_content=extract_content(url_list)
  concatenated_content = ' '.join(output_content)
  merged_document = Document(page_content=concatenated_content,metadata="")
  resulted_content = [merged_document]


  final_output=generate_output(resulted_content)
  if(len(final_output)>0):
    finalDict.append(final_output[0])
# Out:
# https://www.ci.richmond.ca.us/1404/Major-Projects
# https://www.bakersfieldcity.us/518/Projects-Programs
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:94: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:116: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:141: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# https://www.cityofwasco.org/311/Current-Projects
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:94: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:116: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:141: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# https://www.eurekaca.gov/744/Upcoming-Projects
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:94: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:116: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:141: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# https://www.cityofarcata.org/413/Current-City-Construction-Projects
# https://www.mckinleyvillecsd.com/news-and-project-updates
# https://www.cityofsanrafael.org/major-planning-projects-2/
# https://www.novato.org/government/community-development/planning-division/planning-projects?locale=en
# https://www.cityofmillvalley.org/258/Projects
# https://riversideca.gov/utilities/projects
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:94: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:116: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:141: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# https://www.moval.org/cdd/documents/about-projects.html
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:94: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:116: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:141: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# https://www.coronaca.gov/government/departments-divisions/department-of-water-and-power/construction
# http://www.cityofsacramento.org/public-works/engineering-services/projects
# https://data.ca.gov/dataset/?q=construction+and+infrastructure+projects&sort=score+desc%2C+metadata_modified+desc
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:94: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:116: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:141: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# https://dot.ca.gov/programs/procurement-and-contracts/bid-opportunities
# https://www.cityofarcata.org/413/Current-City-Construction-Projects
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:94: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:116: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:141: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# https://www.cityofsanrafael.org/major-planning-projects-2/
# https://www.elkgrovecity.org/southeast-policy-area/development-projects
# https://www.fluor.com/market-reach/industries/infrastructure
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:94: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:116: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:141: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# https://www.fluor.com/projects
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:94: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:116: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_transformers/beautiful_soup_transformer.py:141: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, "html.parser")
# https://www.toaks.org/departments/public-works/construction

# %%
finalDict
# Out:
# [{'original_id': '#ccf5602c1c-2e20-4773-89f3-08f921ac655f',
#   'aug_id': 'Mathieu Court Alley Play Street',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point',
#    'coordinates': [-122.344475, 37.933013]},
#   'url': 'https://www.ci.richmond.ca.us/4486/Travel-Safe-Richmond',
#   'region_name': 'North America',
#   'region_code': 'NA',
#   'Project_title': 'Mathieu Court Alley Play Street',
#   'Project_description': 'The City of Richmond proposes to construct the Richmond-Greenway Gap Closure Project, a multi-use trail connection in Richmond, California. The Richmond-Ohlone Greenway Gap Closure Project represents the third phase of the Richmond Greenway Project, which would provide a continuous bicycle and pedestrian pathway in Richmond from Garrard Boulevard and the Richmond Parkway to San Pablo Avenue. The Richmond Greenway would connect the San Francisco Bay Trail at the west with the Ohlone Greenway in the City of El Cerrito at the east. The proposed project includes installation of the new multi-use trail, a new crosswalk and traffic signal on San Pablo Avenue, and a new bridge over realigned Baxter Creek as well as associated improvements and landscaping.',
#   'status': 'Ongoing',
#   'stages': 'Construction',
#   'date': '2023-02-07',
#   'procurementMethod': 'Public Tender',
#   'budget': None,
#   'currency': 'USD',
#   'buyer': 'City of Richmond',
#   'sector': 'Infrastructure',
#   'subsector': 'Urban Development'},
#  {'original_id': '1',
#   'aug_id': 'About Google Translate',
#   'country_name': 'Google',
#   'country_code': 'GOO',
#   'map_coordinates': {'type': 'Point', 'coordinates': [37.422, -122.084]},
#   'url': 'https://translate.google.com/about/?hl=en-US',
#   'region_name': 'Tech',
#   'region_code': 'TEC',
#   'Project_title': 'Google Translate',
#   'Project_description': 'Translate text, images, documents, and websites',
#   'status': 'active',
#   'stages': 'Ongoing',
#   'date': '2022-03-15',
#   'procurementMethod': 'Online',
#   'budget': 100000,
#   'currency': 'USD',
#   'buyer': 'Google',
#   'sector': 'Technology',
#   'subsector': 'Translation'},
#  {'original_id': '98',
#   'aug_id': 'GIS-Specialist-55',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-119.3528, 35.5941]},
#   'url': 'https://www.cityofwasco.org/Jobs.aspx?UniqueId=98&From=All&CommunityJobs=False&JobID=GIS-Specialist-55',
#   'region_name': 'North America',
#   'region_code': 'NA',
#   'Project_title': 'GIS Specialist',
#   'Project_description': 'Install and maintain a variety of computer-based software and hardware including Geographical Information Systems software (GIS)',
#   'status': 'Open',
#   'stages': 'Posted January 6, 2023 8:00 AM | Open Until Filled',
#   'date': '2023-01-06',
#   'procurementMethod': 'Unknown',
#   'budget': None,
#   'currency': 'Unknown',
#   'buyer': 'City of Wasco',
#   'sector': 'Technology',
#   'subsector': 'Information Technology'},
#  {'original_id': '1',
#   'aug_id': '1',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-124.16367, 40.80207]},
#   'url': 'https://www.eurekaca.gov',
#   'Project_title': 'Capital Improvement Program Report 2024',
#   'Project_description': "The City of Eureka’s Five-Year Capital Improvement Program (CIP) is a multi-year planning instrument used to identify needed capital improvement projects and to coordinate the financing and timing of these improvements. The primary purpose of the CIP is to assist in the orderly implementation of the broad and comprehensive goals of the City’s adopted General Plan. The CIP also aids with planning for maintenance and replacement of the City's infrastructure by establishing an orderly basis to guide local officials in making sound budget decisions. Attention is also focused on community goals, needs, and capabilities to maximize the benefit of public expenditures.",
#   'status': 'ongoing',
#   'stages': 'planning',
#   'date': '2024-01-01',
#   'procurementMethod': 'planning',
#   'budget': 250000,
#   'currency': 'USD',
#   'buyer': 'City of Eureka',
#   'sector': 'Infrastructure',
#   'subsector': 'Public Works'},
#  {'original_id': '1',
#   'aug_id': 'cc8bd95fde-da5f-45d7-9e90-d6e2eb24437f',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-124.0828, 40.8665]},
#   'url': 'https://www.cityofarcata.org/856/Wastewater-Treatment-Facilities-Improvem',
#   'region_name': 'North America',
#   'region_code': 'NA',
#   'Project_title': 'Arcata Wastewater Treatment Facility Improvement Project',
#   'Project_description': 'The City of Arcata proposes to construct upgrades to the existing Arcata Wastewater Treatment Facility to update aging infrastructure and comply with the requirements of the Regional Water Quality Control Board Order No. 1-2019-0006.',
#   'status': 'Ongoing',
#   'stages': 'Phase 1',
#   'date': '2021-07-01',
#   'procurementMethod': 'Construction',
#   'budget': 54000000,
#   'currency': 'USD',
#   'buyer': 'City of Arcata',
#   'sector': 'Water and Sanitation',
#   'subsector': 'Wastewater Treatment'},
#  {'original_id': '1',
#   'aug_id': '1',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-124.1073, 40.9469]},
#   'url': 'https://mckinleyvillecsd.ca.gov/',
#   'region_name': 'North America',
#   'region_code': 'NA',
#   'Project_title': 'McKinleyville BMX Track and Park Construction',
#   'Project_description': 'Request for Bids for the Construction of the McKinleyville BMX Track and Park Project',
#   'status': 'Open',
#   'stages': 'Bids and RFPs',
#   'date': '2024-05-23',
#   'procurementMethod': 'Bids',
#   'budget': None,
#   'currency': 'USD',
#   'buyer': 'McKinleyville Community Services District',
#   'sector': 'Construction',
#   'subsector': 'BMX Track and Park'},
#  {'original_id': '1',
#   'aug_id': 'San Rafael',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-122.5268, 37.9749]},
#   'url': 'https://www.cityofsanrafael.org/',
#   'region_name': 'North America',
#   'region_code': 'NA',
#   'Project_title': 'Planning Division',
#   'Project_description': 'The Planning Division provides information on land use, zoning, site development standards and processes applications for land use permits and land divisions. Most projects submitted fall into two categories, Design Review or Use Permit.',
#   'status': 'active',
#   'stages': 'ongoing',
#   'date': '2024-05-09',
#   'procurementMethod': 'NA',
#   'budget': 0,
#   'currency': 'NA',
#   'buyer': 'City of San Rafael',
#   'sector': 'Urban Planning',
#   'subsector': 'Land Use and Zoning'},
#  {'original_id': '18.52532217.1716126980.5773ca1c',
#   'aug_id': '18.52532217.1716126980.5773ca1c'},
#  {'original_id': 'cc9b263b9d-a7e2-4e23-b747-b6d686e76be0',
#   'aug_id': '27',
#   'country_name': 'Mill Valley',
#   'country_code': 'MVL',
#   'map_coordinates': {'type': 'Point', 'coordinates': [37.9062, -122.5448]},
#   'url': 'https://www.cityofmillvalley.org/',
#   'region_name': 'N/A',
#   'region_code': 'N/A'},
#  {'original_id': '1',
#   'aug_id': 'RPU',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-117.396156, 33.95335]},
#   'url': 'https://www.riversideca.gov/media-press-release/rpu',
#   'region_name': 'North America',
#   'region_code': 'NA',
#   'Project_title': 'Riverside Public Utilities Recognized for Excellence in Communications',
#   'Project_description': 'Riverside Public Utilities has been recognized for excellence in communications.',
#   'status': 'closed',
#   'stages': 'completed',
#   'date': '2022-11-20',
#   'procurementMethod': 'open',
#   'budget': 0,
#   'currency': 'USD',
#   'buyer': 'Riverside Public Utilities',
#   'sector': 'Utilities',
#   'subsector': 'Communications'},
#  {'original_id': '1',
#   'aug_id': '1',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': '', 'coordinates': [33.9425, -118.4081]},
#   'url': 'https://moval.gov/cdd/simplicity-help.html',
#   'region_name': 'California',
#   'region_code': 'CA',
#   'Project_title': 'Building and Safety Applications',
#   'Project_description': 'Choose this to view Digital Plan Room quick tips, video tutorials, etc',
#   'status': 'active',
#   'stages': 'ongoing',
#   'date': '2022-06-01',
#   'procurementMethod': 'Open',
#   'budget': 50000,
#   'currency': 'USD',
#   'buyer': 'City of Moreno Valley',
#   'sector': 'Public Services',
#   'subsector': 'Building and Safety'},
#  {'original_id': '18.56532217.1716127214.11678193',
#   'aug_id': '56532217',
#   'url': 'https://errors.edgesuite.net/18.56532217.1716127214.11678193'},
#  {'original_id': '/content/portal/us/en/city-government/contact-us',
#   'aug_id': 'city-government-contact-us',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'url': 'https://www.cityofsacramento.gov/city-government/contact-us',
#   'region_name': 'California',
#   'region_code': 'CA'},
#  {'original_id': '1',
#   'aug_id': 'california-department-of-fish-and-wildlife',
#   'country_name': 'California Department of Fish and Wildlife',
#   'country_code': 'USA',
#   'region_name': 'California',
#   'region_code': 'US-CA',
#   'url': 'https://example.com',
#   'buyer': 'California Department of Fish and Wildlife',
#   'sector': 'Construction',
#   'subsector': 'Infrastructure',
#   'status': 'Open',
#   'stages': 'Planning',
#   'date': '2023-09-15',
#   'procurementMethod': 'Tender',
#   'budget': 5000000,
#   'currency': 'USD'},
#  {'original_id': '01A6400',
#   'aug_id': '01A6400',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-123.8985, 41.7076]},
#   'url': 'https://caleprocure.ca.gov/event/2660/01A6400',
#   'region_name': 'California',
#   'region_code': 'CA',
#   'Project_title': 'Multi-Provider Title and Escrow Services in Del Norte County',
#   'Project_description': 'Procurement of title and escrow services in Del Norte County',
#   'status': 'active',
#   'stages': 'open',
#   'date': '2024-05-02',
#   'procurementMethod': 'open',
#   'budget': None,
#   'currency': 'USD',
#   'buyer': 'Caltrans',
#   'sector': 'Real Estate',
#   'subsector': 'Title and Escrow Services'},
#  {'original_id': 'Wastewater_Treatment_Facilities_Improvements',
#   'aug_id': 'Arcata_Wastewater_Treatment_Facility',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-124.0818, 40.8665]},
#   'url': 'https://www.cityofarcata.org',
#   'region_name': 'North America',
#   'region_code': 'NA',
#   'Project_title': 'Wastewater Treatment Facilities Improvements',
#   'Project_description': 'The City of Arcata proposes to construct upgrades to the existing Arcata Wastewater Treatment Facility to update aging infrastructure and comply with regulatory requirements.',
#   'status': 'Ongoing',
#   'stages': 'Phase 1: Rehabilitation and reconfiguration of effluent flow',
#   'date': '2023-08-15',
#   'procurementMethod': 'Construction',
#   'budget': 5000000,
#   'currency': 'USD',
#   'buyer': 'City of Arcata',
#   'sector': 'Environmental',
#   'subsector': 'Wastewater Treatment'},
#  {'original_id': '1',
#   'aug_id': 'san_rafael_planning',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-122.5311, 38.0699]},
#   'url': 'https://www.cityofsanrafael.org/',
#   'region_name': 'North America',
#   'region_code': 'NA',
#   'Project_title': 'Planning Division',
#   'Project_description': 'Provides information on land use, zoning, site development standards and processes applications for land use permits and land divisions.',
#   'status': 'Open',
#   'stages': 'Ongoing',
#   'date': '2024-05-17',
#   'procurementMethod': 'Online',
#   'budget': None,
#   'currency': 'USD',
#   'buyer': 'City of San Rafael',
#   'sector': 'Community Development',
#   'subsector': 'Urban Planning'},
#  {'original_id': '1',
#   'aug_id': 'SeeClickFix Elk Grove',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point',
#    'coordinates': [-121.3716184, 38.4087993]},
#   'url': 'https://apps.apple.com/us/app/seeclickfix-elk-grove/id1604852377',
#   'region_name': 'California',
#   'region_code': 'CA',
#   'Project_title': 'SeeClickFix Elk Grove',
#   'Project_description': 'The SeeClickFix Elk Grove app makes reporting a non-emergency problem easier than ever. This free app is a great way for residents of Elk Grove to report issues in the community as soon as they are discovered. This app uses GPS to recognize your location and gives you a menu of common quality-of-life conditions to report a problem. It allows you to upload pictures or videos to accompany your request and gives you the ability to track the issue from the time reported through resolution. The app can be used for a variety of requests such as street maintenance, streetlight requests, damaged trees, abandoned cars, code enforcement issues and more. The City of Elk Grove appreciates your feedback, and use of this software will allow us to improve and beautify our community.',
#   'status': 'active',
#   'stages': 'implementation',
#   'date': '2023-10-24',
#   'procurementMethod': 'Mobile App Development',
#   'budget': 0,
#   'currency': 'USD',
#   'buyer': 'City of Elk Grove',
#   'sector': 'Utilities',
#   'subsector': 'Public Services'},
#  {'original_id': '1',
#   'aug_id': '1',
#   'country_name': 'Global',
#   'country_code': 'GLB',
#   'map_coordinates': {},
#   'url': 'https://www.fluor.com/',
#   'region_name': 'Global',
#   'region_code': 'GLB',
#   'Project_title': 'Infrastructure Projects',
#   'Project_description': 'An Industry Leader in Design and Construction of Infrastructure and Transportation Projects',
#   'status': 'Ongoing',
#   'stages': 'Design and Construction',
#   'date': '2024-09-15',
#   'procurementMethod': 'Design-Build',
#   'budget': 1000000,
#   'currency': 'USD',
#   'buyer': 'Fluor Corporation',
#   'sector': 'Infrastructure',
#   'subsector': 'Transportation'},
#  {'original_id': '1',
#   'aug_id': '1',
#   'country_name': 'Canada',
#   'country_code': 'CAN',
#   'map_coordinates': {'type': 'Point', 'coordinates': [-123.0898, 54.0514]},
#   'url': 'https://www.example.com',
#   'region_name': 'North America',
#   'region_code': 'NA',
#   'Project_title': 'LNG Canada Export Facility',
#   'Project_description': 'The project represents the largest energy investment in Canadian history.',
#   'status': 'closed',
#   'stages': 'construction',
#   'date': '2022-01-15',
#   'procurementMethod': 'open',
#   'budget': 50000000,
#   'currency': 'CAD',
#   'buyer': 'LNG Canada',
#   'sector': 'Energy',
#   'subsector': 'Natural Gas'},
#  {'original_id': '1',
#   'aug_id': 'TO_library',
#   'country_name': 'United States',
#   'country_code': 'USA',
#   'map_coordinates': {'type': 'Point', 'coordinates': [34.1706, -118.8376]},
#   'url': 'http://www.tolibrary.org',
#   'buyer': 'Thousand Oaks Library',
#   'sector': 'Public Services',
#   'subsector': 'Library Services'}]

# %% [markdown]
# # **ouput Dictionary to Dataframe**

# %%
df=pd.DataFrame(finalDict)

# %%
df
# Out:
#                                          original_id  \
# 0            #ccf5602c1c-2e20-4773-89f3-08f921ac655f
# 1                                                  1
# 2                                                 98
# 3                                                  1
# 4                                                  1
# 5                                                  1
# 6                                                  1
# 7                    18.52532217.1716126980.5773ca1c
# 8             cc9b263b9d-a7e2-4e23-b747-b6d686e76be0
# 9                                                  1
# 10                                                 1
# 11                   18.56532217.1716127214.11678193
# 12  /content/portal/us/en/city-government/contact-us
# 13                                                 1
# 14                                           01A6400
# 15      Wastewater_Treatment_Facilities_Improvements
# 16                                                 1
# 17                                                 1
# 18                                                 1
# 19                                                 1
# 20                                                 1
#
#                                         aug_id  \
# 0              Mathieu Court Alley Play Street
# 1                       About Google Translate
# 2                            GIS-Specialist-55
# 3                                            1
# 4       cc8bd95fde-da5f-45d7-9e90-d6e2eb24437f
# 5                                            1
# 6                                   San Rafael
# 7              18.52532217.1716126980.5773ca1c
# 8                                           27
# 9                                          RPU
# 10                                           1
# 11                                    56532217
# 12                  city-government-contact-us
# 13  california-department-of-fish-and-wildlife
# 14                                     01A6400
# 15        Arcata_Wastewater_Treatment_Facility
# 16                         san_rafael_planning
# 17                       SeeClickFix Elk Grove
# 18                                           1
# 19                                           1
# 20                                  TO_library
#
#                                   country_name country_code  \
# 0                                United States          USA
# 1                                       Google          GOO
# 2                                United States          USA
# 3                                United States          USA
# 4                                United States          USA
# 5                                United States          USA
# 6                                United States          USA
# 7                                          NaN          NaN
# 8                                  Mill Valley          MVL
# 9                                United States          USA
# 10                               United States          USA
# 11                                         NaN          NaN
# 12                               United States          USA
# 13  California Department of Fish and Wildlife          USA
# 14                               United States          USA
# 15                               United States          USA
# 16                               United States          USA
# 17                               United States          USA
# 18                                      Global          GLB
# 19                                      Canada          CAN
# 20                               United States          USA
#
#                                       map_coordinates  \
# 0   {'type': 'Point', 'coordinates': [-122.344475,...
# 1   {'type': 'Point', 'coordinates': [37.422, -122...
# 2   {'type': 'Point', 'coordinates': [-119.3528, 3...
# 3   {'type': 'Point', 'coordinates': [-124.16367, ...
# 4   {'type': 'Point', 'coordinates': [-124.0828, 4...
# 5   {'type': 'Point', 'coordinates': [-124.1073, 4...
# 6   {'type': 'Point', 'coordinates': [-122.5268, 3...
# 7                                                 NaN
# 8   {'type': 'Point', 'coordinates': [37.9062, -12...
# 9   {'type': 'Point', 'coordinates': [-117.396156,...
# 10  {'type': '', 'coordinates': [33.9425, -118.4081]}
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  {'type': 'Point', 'coordinates': [-123.8985, 4...
# 15  {'type': 'Point', 'coordinates': [-124.0818, 4...
# 16  {'type': 'Point', 'coordinates': [-122.5311, 3...
# 17  {'type': 'Point', 'coordinates': [-121.3716184...
# 18                                                 {}
# 19  {'type': 'Point', 'coordinates': [-123.0898, 5...
# 20  {'type': 'Point', 'coordinates': [34.1706, -11...
#
#                                                   url    region_name  \
# 0   https://www.ci.richmond.ca.us/4486/Travel-Safe...  North America
# 1        https://translate.google.com/about/?hl=en-US           Tech
# 2   https://www.cityofwasco.org/Jobs.aspx?UniqueId...  North America
# 3                            https://www.eurekaca.gov            NaN
# 4   https://www.cityofarcata.org/856/Wastewater-Tr...  North America
# 5                    https://mckinleyvillecsd.ca.gov/  North America
# 6                    https://www.cityofsanrafael.org/  North America
# 7                                                 NaN            NaN
# 8                   https://www.cityofmillvalley.org/            N/A
# 9   https://www.riversideca.gov/media-press-releas...  North America
# 10         https://moval.gov/cdd/simplicity-help.html     California
# 11  https://errors.edgesuite.net/18.56532217.17161...            NaN
# 12  https://www.cityofsacramento.gov/city-governme...     California
# 13                                https://example.com     California
# 14      https://caleprocure.ca.gov/event/2660/01A6400     California
# 15                       https://www.cityofarcata.org  North America
# 16                   https://www.cityofsanrafael.org/  North America
# 17  https://apps.apple.com/us/app/seeclickfix-elk-...     California
# 18                             https://www.fluor.com/         Global
# 19                            https://www.example.com  North America
# 20                           http://www.tolibrary.org            NaN
#
#    region_code                                      Project_title  \
# 0           NA                    Mathieu Court Alley Play Street
# 1          TEC                                   Google Translate
# 2           NA                                     GIS Specialist
# 3          NaN            Capital Improvement Program Report 2024
# 4           NA  Arcata Wastewater Treatment Facility Improveme...
# 5           NA      McKinleyville BMX Track and Park Construction
# 6           NA                                  Planning Division
# 7          NaN                                                NaN
# 8          N/A                                                NaN
# 9           NA  Riverside Public Utilities Recognized for Exce...
# 10          CA                   Building and Safety Applications
# 11         NaN                                                NaN
# 12          CA                                                NaN
# 13       US-CA                                                NaN
# 14          CA  Multi-Provider Title and Escrow Services in De...
# 15          NA       Wastewater Treatment Facilities Improvements
# 16          NA                                  Planning Division
# 17          CA                              SeeClickFix Elk Grove
# 18         GLB                            Infrastructure Projects
# 19          NA                         LNG Canada Export Facility
# 20         NaN                                                NaN
#
#                                   Project_description   status  \
# 0   The City of Richmond proposes to construct the...  Ongoing
# 1     Translate text, images, documents, and websites   active
# 2   Install and maintain a variety of computer-bas...     Open
# 3   The City of Eureka’s Five-Year Capital Improve...  ongoing
# 4   The City of Arcata proposes to construct upgra...  Ongoing
# 5   Request for Bids for the Construction of the M...     Open
# 6   The Planning Division provides information on ...   active
# 7                                                 NaN      NaN
# 8                                                 NaN      NaN
# 9   Riverside Public Utilities has been recognized...   closed
# 10  Choose this to view Digital Plan Room quick ti...   active
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13                                                NaN     Open
# 14  Procurement of title and escrow services in De...   active
# 15  The City of Arcata proposes to construct upgra...  Ongoing
# 16  Provides information on land use, zoning, site...     Open
# 17  The SeeClickFix Elk Grove app makes reporting ...   active
# 18  An Industry Leader in Design and Construction ...  Ongoing
# 19  The project represents the largest energy inve...   closed
# 20                                                NaN      NaN
#
#                                                stages        date  \
# 0                                        Construction  2023-02-07
# 1                                             Ongoing  2022-03-15
# 2   Posted January 6, 2023 8:00 AM | Open Until Fi...  2023-01-06
# 3                                            planning  2024-01-01
# 4                                             Phase 1  2021-07-01
# 5                                       Bids and RFPs  2024-05-23
# 6                                             ongoing  2024-05-09
# 7                                                 NaN         NaN
# 8                                                 NaN         NaN
# 9                                           completed  2022-11-20
# 10                                            ongoing  2022-06-01
# 11                                                NaN         NaN
# 12                                                NaN         NaN
# 13                                           Planning  2023-09-15
# 14                                               open  2024-05-02
# 15  Phase 1: Rehabilitation and reconfiguration of...  2023-08-15
# 16                                            Ongoing  2024-05-17
# 17                                     implementation  2023-10-24
# 18                            Design and Construction  2024-09-15
# 19                                       construction  2022-01-15
# 20                                                NaN         NaN
#
#          procurementMethod      budget currency  \
# 0            Public Tender         NaN      USD
# 1                   Online    100000.0      USD
# 2                  Unknown         NaN  Unknown
# 3                 planning    250000.0      USD
# 4             Construction  54000000.0      USD
# 5                     Bids         NaN      USD
# 6                       NA         0.0       NA
# 7                      NaN         NaN      NaN
# 8                      NaN         NaN      NaN
# 9                     open         0.0      USD
# 10                    Open     50000.0      USD
# 11                     NaN         NaN      NaN
# 12                     NaN         NaN      NaN
# 13                  Tender   5000000.0      USD
# 14                    open         NaN      USD
# 15            Construction   5000000.0      USD
# 16                  Online         NaN      USD
# 17  Mobile App Development         0.0      USD
# 18            Design-Build   1000000.0      USD
# 19                    open  50000000.0      CAD
# 20                     NaN         NaN      NaN
#
#                                          buyer                 sector  \
# 0                             City of Richmond         Infrastructure
# 1                                       Google             Technology
# 2                                City of Wasco             Technology
# 3                               City of Eureka         Infrastructure
# 4                               City of Arcata   Water and Sanitation
# 5    McKinleyville Community Services District           Construction
# 6                           City of San Rafael         Urban Planning
# 7                                          NaN                    NaN
# 8                                          NaN                    NaN
# 9                   Riverside Public Utilities              Utilities
# 10                       City of Moreno Valley        Public Services
# 11                                         NaN                    NaN
# 12                                         NaN                    NaN
# 13  California Department of Fish and Wildlife           Construction
# 14                                    Caltrans            Real Estate
# 15                              City of Arcata          Environmental
# 16                          City of San Rafael  Community Development
# 17                           City of Elk Grove              Utilities
# 18                           Fluor Corporation         Infrastructure
# 19                                  LNG Canada                 Energy
# 20                       Thousand Oaks Library        Public Services
#
#                     subsector
# 0           Urban Development
# 1                 Translation
# 2      Information Technology
# 3                Public Works
# 4        Wastewater Treatment
# 5          BMX Track and Park
# 6         Land Use and Zoning
# 7                         NaN
# 8                         NaN
# 9              Communications
# 10        Building and Safety
# 11                        NaN
# 12                        NaN
# 13             Infrastructure
# 14  Title and Escrow Services
# 15       Wastewater Treatment
# 16             Urban Planning
# 17            Public Services
# 18             Transportation
# 19                Natural Gas
# 20           Library Services

# %% [markdown]
# # **Dataframe to Json**

# %%
df_json = df.to_json(orient='records', indent=4)

# %%
df_json
# Out:
# '[\n    {\n        "original_id":"#ccf5602c1c-2e20-4773-89f3-08f921ac655f",\n        "aug_id":"Mathieu Court Alley Play Street",\n        "country_name":"United States",\n        "country_code":"USA",\n        "map_coordinates":{\n            "type":"Point",\n            "coordinates":[\n                -122.344475,\n                37.933013\n            ]\n        },\n        "url":"https:\\/\\/www.ci.richmond.ca.us\\/4486\\/Travel-Safe-Richmond",\n        "region_name":"North America",\n        "region_code":"NA",\n        "Project_title":"Mathieu Court Alley Play Street",\n        "Project_description":"The City of Richmond proposes to construct the Richmond-Greenway Gap Closure Project, a multi-use trail connection in Richmond, California. The Richmond-Ohlone Greenway Gap Closure Project represents the third phase of the Richmond Greenway Project, which would provide a continuous bicycle and pedestrian pathway in Richmond from Garrard Boulevard and the Richmond Parkway to San Pablo Avenue. The Richmond Greenway would connect the San Francisco Bay Trail at the west with the Ohlone Greenway in the City of El Cerrito at the east. The proposed project includes installation of the new multi-use trail, a new crosswalk and traffic signal on San Pablo Avenue, and a new bridge over realigned Baxter Creek as well as associated improvements and landscaping.",\n        "status":"Ongoing",\n        "stages":"Construction",\n        "date":"2023-02-07",\n        "procurementMethod":"Public Tender",\n        "budget":null,\n        "currency":"USD",\n        "buyer":"City of Richmond",\n        "sector":"Infrastructure",\n        "subsector":"Urban Development"\n    },\n    {\n        "original_id":"1",\n        "aug_id":"About Google Translate",\n        "country_name":"Google",\n        "country_code":"GOO",\n        "map_coordinates":{\n            "type":"Point",\n            "coordinates":[\n                37.422,\n                -122.084\n            ]\n        },\n        "url":"https:\\/\\/translate.google.com\\/about\\/?hl=en-US",\n        "region_name":"Tech",\n        "region_code":"TEC",\n        "Project_title":"Google Translate",\n        "Project_description":"Translate text, images, documents, and websites",\n        "status":"active",\n        "stages":"Ongoing",\n        "date":"2022-03-15",\n        "procurementMethod":"Online",\n        "budget":100000.0,\n        "currency":"USD",\n        "buyer":"Google",\n        "sector":"Technology",\n        "subsector":"Translation"\n    },\n    {\n        "original_id":"98",\n        "aug_id":"GIS-Specialist-55",\n        "country_name":"United States",\n        "country_code":"USA",\n        "map_coordinates":{\n            "type":"Point",\n            "coordinates":[\n                -119.3528,\n                35.5941\n            ]\n        },\n        "url":"https:\\/\\/www.cityofwasco.org\\/Jobs.aspx?UniqueId=98&From=All&CommunityJobs=False&JobID=GIS-Specialist-55",\n        "region_name":"North America",\n        "region_code":"NA",\n        "Project_title":"GIS Specialist",\n        "Project_description":"Install and maintain a variety of computer-based software and hardware including Geographical Information Systems software (GIS)",\n        "status":"Open",\n        "stages":"Posted January 6, 2023 8:00 AM | Open Until Filled",\n        "date":"2023-01-06",\n        "procurementMethod":"Unknown",\n        "budget":null,\n        "currency":"Unknown",\n        "buyer":"City of Wasco",\n        "sector":"Technology",\n        "subsector":"Information Technology"\n    },\n    {\n        "original_id":"1",\n        "aug_id":"1",\n        "country_name":"United States",\n        "country_code":"USA",\n        "map_coordinates":{\n            "type":"Point",\n            "coordinates":[\n                -124.16367,\n                40.80207\n            ]\n        },\n        "url":"https:\\/\\/www.eurekaca.gov",\n        "region_name":null,\n        "region_code":null ...

# %% [markdown]
# # **Save the JSON**

# %%
with open('/content/drive/MyDrive/Colab Notebooks/Scraped.json', 'w') as file:
    file.write(df_json)

# %% [markdown]
# # **Save the Dataframe as a CSV File**

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Scraped_URL_Data.csv', index=False)

# %% [markdown]
# # **Run Streamlit web app in Collab notebook**

# %% [markdown]
# **Below is the code saved in Web_scrapping_streamlit.py.py. It is a streamlit web app for user interaction**
#
# > Add blockquote

# %%
import nest_asyncio
import time
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import AsyncChromiumLoader
from langchain_community.document_transformers import BeautifulSoupTransformer
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import create_extraction_chain
from google.colab import userdata
import comet_llm
import streamlit as st

nest_asyncio.apply()

MY_OPENAI_KEY = ""
MY_COMET_KEY = ""

comet_llm.init(project="langchain-web-scraping", api_key=MY_COMET_KEY)

html_tags = [
    "h1", "h2", "h3", "h4", "h5", "h6",
    "p",
    "span",
    "div",
    "ul", "ol", "li",
    "table", "tr", "th", "td",
    "a",
    "b", "strong",
    "i", "em",
    "blockquote", "q", "cite",
    "code", "pre",
    "form", "input", "textarea", "label",
    "dl", "dt", "dd",
    "article",
    "section",
    "nav",
    "aside",
    "header",
    "footer",
    "main",
    "figure", "figcaption",
    "details", "summary",
    "mark",
    "time"
]

def extract_url(url):
    print(url)
    url_loader = AsyncChromiumLoader([url])
    url_docs = url_loader.load()
    bs_transformer = BeautifulSoupTransformer()
    url_transfornm = bs_transformer.transform_documents(
        url_docs, tags_to_extract=["a"]
    )
    llm = ChatOpenAI(openai_api_key=MY_OPENAI_KEY)
    url_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=15000, chunk_overlap=0)
    url_splits = url_splitter.split_documents(url_transfornm)

    url_schema = {
        "properties": {
            "url": {"type": "string"},
        },
        "required": ["url"],
    }
    url_list = []

    if len(url_splits) > 0:
        start_time = time.time()
        extracted_content = create_extraction_chain(schema=url_schema, llm=llm).run(url_splits[0].page_content)
        end_time = time.time()
        comet_llm.log_prompt(
            prompt=str(url_splits[0].page_content),
            metadata={"schema": url_schema},
            output=extracted_content,
            duration=end_time - start_time,
        )
        url_list = [d['url'] for d in extracted_content]

    return url_list

def extract_content(urls):
    contents = []
    for url in urls:
        url_loader = AsyncChromiumLoader([url])
        content_docs = url_loader.load()
        bs_transformer = BeautifulSoupTransformer()
        content_transfornm = bs_transformer.transform_documents(content_docs, tags_to_extract=html_tags)
        content = content_transfornm[0].page_content
        contents.append(content)
    return contents

class Document:
    def __init__(self, page_content, metadata):
        self.page_content = page_content
        self.metadata = metadata

    def __repr__(self):
        return f'Document(page_content="{self.page_content},metadata={self.metadata} ")'

def generate_output(resulted_content):
    llm = ChatOpenAI(openai_api_key=MY_OPENAI_KEY)
    splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=15000, chunk_overlap=0)
    splits = splitter.split_documents(resulted_content)
    schema = {
        "properties": {
            "original_id": {"type": "string", "description": "Unique from source"},
            "aug_id": {"type": "string", "description": "Augmented identifier from the context"},
            "country_name": {"type": "string", "description": "Name of the Country"},
            "country_code": {"type": "string", "description": "ISO 3-letter Country Code"},
            "map_coordinates": {
                "type": "object",
                "description": "Geo Point of the region formatted as {'type': 'Point', 'coordinates': [longitude, latitude]}",
                "properties": {"type": {"type": "string"}, "coordinates": {"type": "array", "items": {"type": "number"}}},
            },
            "url": {"type": "string", "description": "Url of the website of the source", "format": "uri"},
            "region_name": {"type": "string", "description": "Region Name for a Country according to World Bank Standards"},
            "region_code": {"type": "string", "description": "Region code for a Region according to World Bank Standards"},
            "Project_title": {"type": "string", "description": "A title for this tender/project used as a headline"},
            "Project_description": {"type": "string", "description": "A summary description of the tender/project"},
            "status": {"type": "string", "description": "The current status of the tender/project from the closed tenderStatus codelist"},
            "stages": {"type": "string", "description": "Stages of the tender/project"},
            "date": {"type": "string", "description": "The date on which the information was first recorded or published", "format": "date"},
            "procurementMethod": {"type": "string", "description": "The procedure used to purchase the relevant works, goods or services"},
            "budget": {"type": "number", "description": "The total upper estimated value of the procurement"},
            "currency": {"type": "string", "description": "The currency for each amount specified using the uppercase 3-letter code from ISO4217"},
            "buyer": {"type": "string", "description": "Entity whose budget will be used to pay for related goods, works or services"},
            "sector": {"type": "string", "description": "A high-level categorization of the main sector this procurement process relates to"},
            "subsector": {"type": "string", "description": "A further subdivision of the sector the procurement process belongs to"},
        },
        "required": [
            "original_id", "aug_id", "country_name", "country_code", "map_coordinates", "url",
            "region_name", "region_code", "title", "description", "status", "stages", "date",
            "procurementMethod", "budget", "currency", "buyer", "sector", "subsector"
        ]
    }

    if len(splits) > 0:
        start_time = time.time()
        extracted_content = create_extraction_chain(schema=schema, llm=llm).run(splits[0].page_content)
        end_time = time.time()

        comet_llm.log_prompt(
            prompt=str(splits[0].page_content),
            metadata={"schema": schema},
            output=extracted_content,
            duration=end_time - start_time,
        )

    return extracted_content

def main():
    st.title("web scrapper")
    st.write("Enter a URL")
    urls = st.text_area("List Of urls", height=200)
    st.write("Enter your URL List  separated by commas (Ex: url1, url3, url3)")
    urls = [item.strip() for item in urls.split(",")]

    # Submit button
    if st.button("Submit"):
      finalDict=[]
      for url in urls:
        url_list=extract_url(url)
        url_list.append(url)
        output_content=extract_content(url_list)
        concatenated_content = ' '.join(output_content)
        merged_document = Document(page_content=concatenated_content,metadata="")
        resulted_content = [merged_document]
        final_output=generate_output(resulted_content)

        if(len(final_output)>0):
          finalDict.append(final_output[0])

      df=pd.DataFrame(finalDict)
      st.dataframe(df)


if __name__ == "__main__":
    main()

# %%
# !pip install streamlit
# !pip install pytube
# !npm install localtunnel
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (1.34.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<25,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.0.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Requirement already satisfied: pytube in /usr/local/lib/python3.10/dist-packages (15.0.0)
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 0.659s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 2 moderate severity vulnerabilities
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# !streamlit run /content/drive/MyDrive/ColabNotebooks/Web_scrapping_streamlit.py &>/content/logs.txt &

# %%
# !wget -q -O - https://loca.lt/mytunnelpassword
# Out:
# 35.185.1.147

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 3.073s
# your url is: https://mean-trees-relate.loca.lt
# ^C
